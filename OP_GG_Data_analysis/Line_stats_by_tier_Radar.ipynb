# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

# %%
constant_patch = '11.23.1'

# 라이엇 개발자 페이지에서 최신 버전 한국 서버 챔피언 정보 가져오기
champion_info = requests.get("http://ddragon.leagueoflegends.com/cdn/" + constant_patch + "/data/ko_KR/champion.json").json()

# %%
# 챔피언 정보 => DataFrame으로 변환
# champion_df는 'key'로 id값, 'name'으로 챔피언 한국어 이름을 가지는 156rows짜리 DataFrame
champion_df = pd.DataFrame(champion_info['data']).T[['key', 'name']]

# champion_df의 'key' column string => numeric 변환
champion_df['key'] = pd.to_numeric(champion_df['key'])

# %%
df = pd.read_csv('11.23.csv', index_col=0)
# Out:
# C:\Users\power\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df = df.merge(champion_df, how = 'left', left_on = 'championId', right_on = 'key')

# %%
data = pd.DataFrame()
data = df[['tierRank', 'position', 'name', 'result']]

# %%
# 결측치 드랍
data = data.dropna(axis=0)
# 다시하기 드랍
data.drop(data.loc[data['result']=='UNKNOWN'].index, inplace=True)
print('data : ', len(data))
# Out:
# data :  5065150

# %%
# result 숫자로 변환
data.loc[data['result'] == 'WIN', 'result'] = 1
data.loc[data['result'] == 'LOSE', 'result'] = 0
data['games'] = 1
data = data.astype({'result' : 'int'})
# result -> wins로 컬럼명 변경
data.rename(columns = {'result':'wins'},inplace=True)

# %%
# 티어별 데이터 프레임 생성
TierList = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND',
        'MASTER', 'GRAND_MASTER','CHALLENGER']
TierFront = ['I', 'B', 'S', 'G', 'P', 'D', 'M', 'G', 'C']

for i, j in zip(TierList, TierFront) :
    globals()[f'{i}'] = data[data['tierRank'].str.contains(f'{j}')]

low_list = ['I', 'B', 'S', 'G']
low_list = '|'.join(low_list)
LOW_TIER = data[data['tierRank'].str.contains(low_list)]
mid_list = ['P', 'D']
mid_list = '|'.join(mid_list)
MID_TIER = data[data['tierRank'].str.contains(mid_list)]
high_list = ['M', 'R', 'C']
high_list = '|'.join(high_list)
HIGH_TIER = data[data['tierRank'].str.contains(high_list)]

#print('SUM : ', len(IRON)+len(BRONZE)+len(SILVER)+len(GOLD)+len(PLATINUM)+len(DIAMOND)+len(HIGH_TIER))
#print('SUM : ', len(LOW_TIER)+len(MID_TIER)+len(HIGH_TIER))

# %%
# 티어별-포지션별 승률, 픽률
LOW_TIER_total = LOW_TIER.groupby(['position', 'name'], as_index=False).sum()
LOW_TIER_sum = LOW_TIER.groupby(['position'], as_index=False).sum()
LOW_TIER_sum.columns = ['position', 'wins', 'total_games']
LOW_TIER_sum = LOW_TIER_sum[['position', 'total_games']]
LOW_TIER_total = LOW_TIER_total.merge(LOW_TIER_sum, how = 'left', on = 'position')
LOW_TIER_total = LOW_TIER_total[LOW_TIER_total.games > 50]
LOW_TIER_total['winRate'] = LOW_TIER_total['wins'] / LOW_TIER_total['games']
LOW_TIER_total['pickRate'] = LOW_TIER_total['games'] / LOW_TIER_total['total_games']
LOW_TIER_total = LOW_TIER_total.sort_values(by=['position', 'winRate', 'pickRate'], ascending=False) 

MID_TIER_total = MID_TIER.groupby(['position', 'name'], as_index=False).sum()
MID_TIER_sum = MID_TIER.groupby(['position'], as_index=False).sum()
MID_TIER_sum.columns = ['position', 'wins', 'total_games']
MID_TIER_sum = MID_TIER_sum[['position', 'total_games']]
MID_TIER_total = MID_TIER_total.merge(MID_TIER_sum, how = 'left', on = 'position')
MID_TIER_total = MID_TIER_total[MID_TIER_total.games > 50]
MID_TIER_total['winRate'] = MID_TIER_total['wins'] / MID_TIER_total['games']
MID_TIER_total['pickRate'] = MID_TIER_total['games'] / MID_TIER_total['total_games']
MID_TIER_total = MID_TIER_total.sort_values(by=['position', 'winRate', 'pickRate'], ascending=False) 

HIGH_TIER_total = HIGH_TIER.groupby(['position', 'name'], as_index=False).sum()
HIGH_TIER_sum = HIGH_TIER.groupby(['position'], as_index=False).sum()
HIGH_TIER_sum.columns = ['position', 'wins', 'total_games']
HIGH_TIER_sum = HIGH_TIER_sum[['position', 'total_games']]
HIGH_TIER_total = HIGH_TIER_total.merge(HIGH_TIER_sum, how = 'left', on = 'position')
HIGH_TIER_total = HIGH_TIER_total[HIGH_TIER_total.games > 50]
HIGH_TIER_total['winRate'] = HIGH_TIER_total['wins'] / HIGH_TIER_total['games']
HIGH_TIER_total['pickRate'] = HIGH_TIER_total['games'] / HIGH_TIER_total['total_games']
HIGH_TIER_total = HIGH_TIER_total.sort_values(by=['position', 'winRate', 'pickRate'], ascending=False)

# %%
P = ['T','J', 'M','A','S']
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
#tier = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND', 'MASTER', 'GRAND_MASTER','CHALLENGER', 'ABOVE_MASTER']
for i in tier:
    for j, k in zip(line, P):
        a = globals()[f'{i}_total']
        globals()[f'{i}_{j}'] = a[a['position'] == f'{k}'].sort_values(by=['pickRate'], ascending=False).head(5)

# %%
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
columns = ['name']
count = [1, 2, 3, 4, 5]

for i in tier :
    for j in line :
        globals()[f'{i}_{j}'] = globals()[f'{i}_{j}'][columns]
        globals()[f'{i}_{j}'].insert(0, 'rank', count)
        globals()[f'{i}_{j}'] = globals()[f'{i}_{j}'].T

# %%
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

for i in tier :
    for j in line :
        globals()[f'{i}_{j}'].rename(columns=globals()[f'{i}_{j}'].iloc[0],inplace=True)
        globals()[f'{i}_{j}'] = globals()[f'{i}_{j}'].drop(globals()[f'{i}_{j}'].index[0])

# %%
TOP = pd.concat([LOW_TIER_TOP, MID_TIER_TOP, HIGH_TIER_TOP], ignore_index=True)
TOP.index=['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

JUG = pd.concat([LOW_TIER_JUG, MID_TIER_JUG, HIGH_TIER_JUG], ignore_index=True)
JUG.index=['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

MID = pd.concat([LOW_TIER_MID, MID_TIER_MID, HIGH_TIER_MID], ignore_index=True)
MID.index=['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

AD = pd.concat([LOW_TIER_AD, MID_TIER_AD, HIGH_TIER_AD], ignore_index=True)
AD.index=['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

SUP = pd.concat([LOW_TIER_SUP, MID_TIER_SUP, HIGH_TIER_SUP], ignore_index=True)
SUP.index=['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

# %%
AD
# Out:
#               1     2      3      4     5
# LOW_TIER   이즈리얼     진   케이틀린  미스 포츈   징크스
# MID_TIER      진  이즈리얼   케이틀린    징크스   루시안
# HIGH_TIER     진   징크스  아펠리오스   케이틀린  이즈리얼

# %%
LOW_TIER_TOP.rename(index={'name':'LOW_TIER_TOP'}, inplace=True)
LOW_TIER_TOP
# Out:
#                 1   2     3   4   5
# LOW_TIER_TOP  제이스  티모  다리우스  세트  카밀

# %%
count = [1, 2, 3, 4, 5]
HIGH_TIER_TOP.insert(0, 'rank', count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6c91bd245053> in <module>
#       1 count = [1, 2, 3, 4, 5]
# ----> 2 HIGH_TIER_TOP.insert(0, 'rank', count)
#       3 HIGH_TIER_TOP.T
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert rank, already exists

# %%
data = pd.read_csv('json_champ.csv', index_col=0)

# %%
json_champ = data.merge(champion_df, how = 'left', left_on = 'championId', right_on = 'key')

# %%
json_champ['name_x'] = json_champ['name_y']

# %%
json_champ = json_champ.iloc[:,0:11]

# %%
#son_champ['name' == '이즈리얼']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-357a27568e17> in <module>
# ----> 1 json_champ['name' == '이즈리얼']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: False

# %%
#data.loc[data['name_x' == '이즈리얼', 'style' : 'utility'] = (4, 1, 'kPhysical', 3, 1, 1, 3, 1)
# Out:
#   File "<ipython-input-32-fa8c9d81fcb9>", line 1
#     data.loc[data['name_x' == '이즈리얼', 'style' : 'utility'] = (4, 1, 'kPhysical', 3, 1, 1, 3, 1)
#                                                            ^
# SyntaxError: invalid syntax

# %%
pd.set_option('display.max_rows', None)
json_champ
# Out:
#         name_x  style  difficulty damageType  damage  durability  \
# 0           그웬      5           2     kMagic       3           2
# 1          릴리아      8           3     kMagic       3           1
# 2           세트      4           2  kPhysical       2           2
# 3           요네      5           3     kMixed       3           1
# 4           벡스      9           2     kMagic       3           2
# 5          파이크      7           2  kPhysical       2           1
# 6            렐      9           2     kMagic       1           3
# 7        아펠리오스      3           3  kPhysical       3           1
# 8           니코      8           1     kMagic       3           1
# 9         사일러스      7           3     kMagic       2           2
# 10          오른      7           2     kMixed       1           3
# 11          자야      4           2  kPhysical       3           2
# 12          라칸      9           2     kMagic       1           2
# 13          바드      7           3     kMagic       1           1
# 14        칼리스타      2           3  kPhysical       3           1
# 15         아이번      1           3     kMagic       1           1
# 16         렉사이      4           2  kPhysical       2           2
# 17        일라오이      7           2  kPhysical       3           2
# 18         쓰레쉬      8           3     kMagic       1           2
# 19         사미라      1           2  kPhysical       3           2
# 20          유미     10           1     kMagic       1           1
# 21         아지르      5           3     kMagic       3           1
# 22          나미      9           2     kMagic       1           1
# 23        아트록스      3           2  kPhysical       3           3
# 24          바이      6           1  kPhysical       2           2
# 25         키아나      7           3  kPhysical       3           1
# 26          에코      8           3     kMagic       3           2
# 27         클레드      3           2  kPhysical       3           2
# 28          제드      6           3  kPhysical       3           1
# 29         루시안      4           2  kPhysical       3           1
# 30          세나      3           2  kPhysical       2           1
# 31         비에고      3           3  kPhysical       3           1
# 32        탐 켄치      7           1     kMagic       2           3
# 33         징크스      2           2  kPhysical       3           1
# 34        킨드레드      3           3  kPhysical       3           1
# 35           진      3           2  kPhysical       3           1
# 36         브라움      9           2     kMagic       1           2
# 37         아크샨      1           3  kPhysical       3           1
# 38          카밀      4           3  kPhysical       3           2
# 39         탈리야     10           2     kMagic       3           1
# 40         벨코즈     10           2     kMagic       3           1
# 41         야스오      3           3  kPhysical       3           1
# 42          자크     10           1     kMagic       2           3
# 43          나르      5           3  kPhysical       2           3
# 44         세라핀     10           1     kMagic       3           1
# 45         카이사      2           2     kMixed       3           1
# 46         자이라     10           2     kMagic       3           1
# 47          조이     10           3     kMagic       3           1
# 48          케인      1           2  kPhysical       3           1
# 49     아우렐리온 솔     10           3     kMagic       3           1
# 50         신드라     10           2     kMagic       3           1
# 51           퀸      3           2  kPhysical       3           1
# 52        다이애나      7           1     kMagic       3           2
# 53        리산드라     10           2     kMagic       3           1
# 54         제이스      5           2  kPhysical       3           1
# 55        다리우스      6           2  kPhysical       3           2
# 56         카직스      6           2  kPhysical       3           1
# 57         헤카림      7           2  kPhysical       2           2
# 58        드레이븐      2           3  kPhysical       3           1
# 59          룰루      8           2     kMagic       2           1
# 60          직스      9           2     kMagic       3           1
# 61         피오라      3           3  kPhysical       3           2
# 62        세주아니      8           2     kMagic       2           2
# 63         빅토르      9           3     kMagic       3           1
# 64        노틸러스      8           2     kMagic       1           3
# 65         바루스      3           2  kPhysical       3           1
# 66          렝가      4           2  kPhysical       3           1
# 67        볼리베어      4           1  kPhysical       2           3
# 68          피즈      9           3     kMagic       3           1
# 69       그레이브즈      3           2  kPhysical       3           2
# 70          아리     10           2     kMagic       3           1
# 71         쉬바나      6           1  kPhysical       2           2
# 72         제라스      9           2     kMagic       3           1
# 73          럭스      9           1     kMagic       3           1
# 74           쉔      5           2     kMixed       2           3
# 75         코그모      2           2     kMixed       3           1
# 76          리븐      8           2  kPhysical       3           2
# 77          탈론      7           2  kPhysical       3           1
# 78         말자하     10           1     kMagic       3           1
# 79         레오나      9           1     kMagic       1           3
# 80          가렌      8           1  kPhysical       2           3
# 81          케넨      7           2     kMagic       3           1
# 82         아칼리      7           2     kMixed       3           1
# 83          요릭      6           2     kMixed       2           2
# 84       모데카이저      8           2     kMagic       3           2
# 85        이즈리얼      1           1     kMagic       1           1
# 86         판테온      8           1  kPhysical       3           2
# 87        그라가스      9           2     kMagic       2           3
# 88          뽀삐      8           2  kPhysical       2           3
# 89         우디르      4           2     kMixed       2           3
# 90         니달리      8           3     kMagic       3           1
# 91         나서스      3           1  kPhysical       2           3
# 92       하이머딩거     10           2     kMagic       3           1
# 93         스카너      5           1     kMixed       1           3
# 94       카시오페아     10           3     kMagic       3           1
# 95          럼블      9           3     kMagic       3           2
# 96          베인      1           2  kPhysical       3           1
# 97         리 신      6           3  kPhysical       3           2
# 98         브랜드     10           2     kMagic       3           1
# 99          오공      6           1  kPhysical       2           2
# 100       오리아나      9           2     kMagic       2           1
# 101        엘리스      7           3     kMagic       2           2
# 102     자르반 4세      6           1  kPhysical       2           2
# 103        레넥톤      5           1  kPhysical       2           2
# 104       마오카이      8           1     kMagic       1           3
# 105         녹턴      4           1  kPhysical       3           1
# 106       카타리나     10           3     kMagic       3           1
# 107       말파이트      8           1     kMagic       1           3
# 108     블리츠크랭크      9           1     kMagic       1           2
# 109       케이틀린      2           1  kPhysical       3           1
# 110        스웨인     10           2     kMagic       2           2
# 111        트런들      3           1  kPhysical       2           3
# 112        베이가     10           2     kMagic       3           1
# 113         타릭      8           2     kMagic       1           2
# 114        카르마     10           1     kMagic       2           1
# 115        코르키      5           2     kMixed       3           1
# 116       갱플랭크      8           3  kPhysical       3           1
# 117         잔나     10           1     kMagic       1           1
# 118       이렐리아      4           3     kMixed       2           2
# 119        카사딘      9           2     kMagic       3           2
# 120         소나      9           1     kMagic       2           1
# 121      문도 박사      6           1     kMixed       2           3
# 122         샤코      5           2  kPhysical       3           1
# 123       애니비아     10           3     kMagic       3           1
# 124        람머스      7           1     kMixed       2           3
# 125        아무무      9           1     kMagic       2           3
# 126        초가스      7           1     kMagic       2           3
# 127        카서스     10           2     kMagic       3           1
# 128        트위치      1           2  kPhysical       3           1
# 129        이블린      8           2     kMagic       2           2
# 130        신지드     10           2     kMagic       2           3
# 131        질리언     10           2     kMagic       2           1
# 132       모르가나     10           1     kMagic       2           1
# 133         잭스      2           2     kMixed       3           2
# 134      트린다미어      2           1  kPhysical       3           2
# 135         애쉬      3           1  kPhysical       2           1
# 136      미스 포츈      4           1  kPhysical       3           1
# 137    누누와 윌럼프      8           1     kMagic       1           3
# 138         워윅      4           1     kMixed       2           2
# 139      트리스타나      3           1  kPhysical       3           1
# 140         티모      4           1     kMagic       3           1
# 141        소라카     10           1     kMagic       1           1
# 142        시비르      2           2  kPhysical       3           1
# 143        사이온      7           1  kPhysical       2           3
# 144        라이즈     10           2     kMagic       3           1
# 145       알리스타      7           1     kMagic       1           3
# 146      마스터 이      2           1  kPhysical       3           1
# 147         케일      3           2     kMixed       3           1
# 148       피들스틱     10           2     kMagic       3           1
# 149      블라디미르     10           2     kMagic       3           2
# 150        르블랑     10           3     kMagic       3           1
# 151        우르곳      6           2  kPhysical       2           2
# 152       신 짜오      4           1  kPhysical       2           2
# 153  트위스티드 페이트      7           2     kMagic       3           1
# 154        갈리오     10           2     kMagic       2           3
# 155        올라프      4           2  kPhysical       2           2
# 156         애니     10           1     kMagic       3           1
#
#      crowdControl  mobility  utility                     roles  key
# 0               1         3        1   ['fighter', 'assassin']  887
# 1               2         2        2       ['fighter', 'mage']  876
# 2               2         2        1       ['fighter', 'tank']  875
# 3               2         3        1   ['assassin', 'fighter']  777
# 4               2         2        1                  ['mage']  711
# 5               3         3        1   ['support', 'assassin']  555
# 6               3         2        2                  ['tank']  526
# 7               2         1        1              ['marksman']  523
# 8               3         1        1       ['mage', 'support']  518
# 9               1         3        1      ['mage', 'assassin']  517
# 10              3         1        2       ['tank', 'fighter']  516
# 11              3         1        1              ['marksman']  498
# 12              3         3        3               ['support']  497
# 13              3         2        3       ['support', 'mage']  432
# 14              1         3        2              ['marksman']  429
# 15              3         2        3       ['support', 'mage']  427
# 16              2         2        2               ['fighter']  421
# 17              1         1        1       ['fighter', 'tank']  420
# 18              3         1        3    ['support', 'fighter']  412
# 19              1         3        1              ['marksman']  360
# 20              1         3        3       ['support', 'mage']  350
# 21              2         2        1      ['mage', 'marksman']  268
# 22              3         1        2       ['support', 'mage']  267
# 23              2         2        2       ['fighter', 'tank']  266
# 24              3         2        1   ['fighter', 'assassin']  254
# 25              2         2        1   ['assassin', 'fighter']  246
# 26              2         3        1   ['assassin', 'fighter']  245
# 27              1         3        1       ['fighter', 'tank']  240
# 28              1         3        1              ['assassin']  238
# 29              1         3        1              ['marksman']  236
# 30              2         1        3   ['marksman', 'support']  235
# 31              2         2        1   ['assassin', 'fighter']  234
# 32              2         1        3       ['support', 'tank']  223
# 33              2         1        1              ['marksman']  222
# 34              2         3        2              ['marksman']  203
# 35              2         1        1      ['marksman', 'mage']  202
# 36              3         1        2       ['support', 'tank']  201
# 37              1         3        2  ['marksman', 'assassin']  166
# 38              2         3        1       ['fighter', 'tank']  164
# 39              2         1        3       ['mage', 'support']  163
# 40              2         1        1                  ['mage']  161
# 41              2         3        2   ['fighter', 'assassin']  157
# 42              3         2        1       ['tank', 'fighter']  154
# 43              2         2        1       ['fighter', 'tank']  150
# 44              3         1        2       ['mage', 'support']  147
# 45              0         3        1              ['marksman']  145
# 46              3         1        1       ['mage', 'support']  143
# 47              2         2        1       ['mage', 'support']  142
# 48              1         3        1   ['fighter', 'assassin']  141
# 49              2         2        1                  ['mage']  136
# 50              2         1        1       ['mage', 'support']  134
# 51              2         3        1  ['marksman', 'assassin']  133
# 52              2         2        1       ['fighter', 'mage']  131
# 53              3         2        1                  ['mage']  127
# 54              1         2        2   ['fighter', 'marksman']  126
# 55              2         1        1       ['fighter', 'tank']  122
# 56              1         2        1              ['assassin']  121
# 57              2         2        1       ['fighter', 'tank']  120
# 58              1         2        1              ['marksman']  119
# 59              2         1        3       ['support', 'mage']  117
# 60              2         2        1                  ['mage']  115
# 61              2         2        2   ['fighter', 'assassin']  114
# 62              3         2        1       ['tank', 'fighter']  113
# 63              2         1        1                  ['mage']  112
# 64              3         1        1       ['tank', 'fighter']  111
# 65              2         1        1      ['marksman', 'mage']  110
# 66              2         2        1   ['assassin', 'fighter']  107
# 67              2         2        1       ['fighter', 'tank']  106
# 68              2         3        1   ['assassin', 'fighter']  105
# 69              1         2        2              ['marksman']  104
# 70              2         3        1      ['mage', 'assassin']  103
# 71              1         2        1       ['fighter', 'tank']  102
# 72              2         1        1                  ['mage']  101
# 73              2         1        2       ['mage', 'support']   99
# 74              2         2        3                  ['tank']   98
# 75              1         1        1      ['marksman', 'mage']   96
# 76              2         3        1   ['fighter', 'assassin']   92
# 77              1         2        1              ['assassin']   91
# 78              3         1        2      ['mage', 'assassin']   90
# 79              3         1        1       ['tank', 'support']   89
# 80              1         1        1       ['fighter', 'tank']   86
# 81              3         1        1      ['mage', 'marksman']   85
# 82              1         3        1              ['assassin']   84
# 83              2         1        2       ['fighter', 'tank']   83
# 84              1         1        2               ['fighter']   82
# 85              1         1        1      ['marksman', 'mage']   81
# 86              2         2        1   ['fighter', 'assassin']   80
# 87              3         2        1       ['fighter', 'mage']   79
# 88              3         2        1       ['tank', 'fighter']   78
# 89              2         2        1       ['fighter', 'tank']   77
# 90              1         3        2      ['assassin', 'mage']   76
# 91              2         1        1       ['fighter', 'tank']   75
# 92              2         1        2       ['mage', 'support']   74
# 93              3         1        1       ['fighter', 'tank']   72
# 94              3         1        1                  ['mage']   69
# 95              2         1        1       ['fighter', 'mage']   68
# 96              2         2        1  ['marksman', 'assassin']   67
# 97              2         3        1   ['fighter', 'assassin']   64
# 98              2         1        1                  ['mage']   63
# 99              2         2        1       ['fighter', 'tank']   62
# 100             2         1        2       ['mage', 'support']   61
# 101             2         2        1       ['mage', 'fighter']   60
# 102             2         2        2       ['tank', 'fighter']   59
# 103             2         2        1       ['fighter', 'tank']   58
# 104             3         1        2          ['tank', 'mage']   57
# 105             2         2        2   ['assassin', 'fighter']   56
# 106             1         3        1      ['assassin', 'mage']   55
# 107             3         1        1       ['tank', 'fighter']   54
# 108             3         1        1       ['tank', 'fighter']   53
# 109             2         2        1              ['marksman']   51
# 110             2         1        1       ['mage', 'fighter']   50
# 111             1         1        2       ['fighter', 'tank']   48
# 112             3         1        1                  ['mage']   45
# 113             2         1        3    ['support', 'fighter']   44
# 114             2         1        2       ['mage', 'support']   43
# 115             1         2        1              ['marksman']   42
# 116             1         1        2               ['fighter']   41
# 117             3         1        3       ['support', 'mage']   40
# 118             2         3        2   ['fighter', 'assassin']   39
# 119             1         3        1      ['assassin', 'mage']   38
# 120             2         1        2       ['support', 'mage']   37
# 121             1         1        1       ['fighter', 'tank']   36
# 122             2         2        2              ['assassin']   35
# 123             3         1        2       ['mage', 'support']   34
# 124             3         2        1       ['tank', 'fighter']   33
# 125             3         1        1          ['tank', 'mage']   32
# 126             2         1        1          ['tank', 'mage']   31
# 127             1         1        2                  ['mage']   30
# 128             1         2        1  ['marksman', 'assassin']   29
# 129             1         2        2      ['assassin', 'mage']   28
# 130             2         2        1       ['tank', 'fighter']   27
# 131             2         2        3       ['support', 'mage']   26
# 132             3         1        2       ['mage', 'support']   25
# 133             2         2        1   ['fighter', 'assassin']   24
# 134             1         2        1   ['fighter', 'assassin']   23
# 135             3         1        2   ['marksman', 'support']   22
# 136             1         1        1              ['marksman']   21
# 137             2         1        2       ['tank', 'fighter']   20
# 138             2         1        1       ['fighter', 'tank']   19
# 139             2         2        1  ['marksman', 'assassin']   18
# 140             2         1        2  ['marksman', 'assassin']   17
# 141             2         1        3       ['support', 'mage']   16
# 142             1         1        2              ['marksman']   15
# 143             3         1        1       ['tank', 'fighter']   14
# 144             2         2        2       ['mage', 'fighter']   13
# 145             3         1        2       ['tank', 'support']   12
# 146             1         2        1   ['assassin', 'fighter']   11
# 147             1         1        3    ['fighter', 'support']   10
# 148             3         1        1       ['mage', 'support']    9
# 149             1         1        1                  ['mage']    8
# 150             2         3        1      ['assassin', 'mage']    7
# 151             2         1        1       ['fighter', 'tank']    6
# 152             2         2        1   ['fighter', 'assassin']    5
# 153             2         2        2                  ['mage']    4
# 154             3         2        1          ['tank', 'mage']    3
# 155             2         1        1       ['fighter', 'tank']    2
# 156             3         1        2                  ['mage']    1

# %%
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
#tier = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND', 'MASTER', 'GRAND_MASTER','CHALLENGER', 'ABOVE_MASTER']
for j in line:
    for i in tier:
        globals()[f'{i}_{j}'] = globals()[f'{i}_{j}'].merge(json_champ, how = 'left', left_on = 'name', right_on = 'name_x')

# %%
HIGH_TIER_TOP

# %%
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
#tier = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND', 'MASTER', 'GRAND_MASTER','CHALLENGER', 'ABOVE_MASTER']
for j in line:
    for i in tier:
        globals()[f'{i}_{j}_mean'] = globals()[f'{i}_{j}'].mean()[5:12]

# %%
# LOW_TIER_AD_mean

# %%
# line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
# tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
# #tier = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND','MASTER', 'GRAND_MASTER','CHALLENGER', 'ABOVE_MASTER']

# for i in tier : 
#     for j in line :
#         aa = globals()[f'{i}_{j}_mean']
#         globals()[f'{i}_{j}_stats'] = [aa[0], aa[1], aa[2], aa[3], aa[4]]

# %%
columns = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']

# %%
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']

for i in tier :
    for j in line :
        a = globals()[f'{i}_{j}_mean']
        globals()[f'{i}_{j}'] = pd.DataFrame(a).T
        globals()[f'{i}_{j}'] = globals()[f'{i}_{j}'][columns]

# %%
tier = ['LOW_TIER', 'MID_TIER', 'HIGH_TIER']
line = ['TOP', 'JUG', 'MID', 'AD', 'SUP']

TOP = pd.concat([LOW_TIER_TOP, MID_TIER_TOP, HIGH_TIER_TOP], ignore_index=True)
TOP.insert(0, 'tier', tier)

JUG = pd.concat([LOW_TIER_JUG, MID_TIER_JUG, HIGH_TIER_JUG], ignore_index=True)
JUG.insert(0, 'tier', tier)

MID = pd.concat([LOW_TIER_MID, MID_TIER_MID, HIGH_TIER_MID], ignore_index=True)
MID.insert(0, 'tier', tier)

AD = pd.concat([LOW_TIER_AD, MID_TIER_AD, HIGH_TIER_AD], ignore_index=True)
AD.insert(0, 'tier', tier)

SUP = pd.concat([LOW_TIER_SUP, MID_TIER_SUP, HIGH_TIER_SUP], ignore_index=True)
SUP.insert(0, 'tier', tier)

# %%
TOP

# %%
#TOP_stats_by_tier
labels = TOP.columns[1:]
num_labels = len(labels)
    
angles = [x / float(num_labels) * (2 * pi) for x in range(num_labels)] 
angles += angles[:1] 
    
my_palette = plt.cm.get_cmap("Set2", len(TOP.index))
 
fig = plt.figure(figsize=(8, 8))
fig.set_facecolor('white')
ax = fig.add_subplot(polar = True)
for i, row in TOP.iterrows():
    color = my_palette(i)
    data = TOP.iloc[i].drop('tier').tolist()
    data += data[:1]
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[: -1], labels, fontsize = 13)
    ax.tick_params(axis='x', which='major', pad = 15)
    
    ax.set_rlabel_position(0)
    plt.yticks([0, 1, 2, 3],['0', '1', '2', '3'], fontsize=10)
    plt.ylim(0, 3)
    
    ax.plot(angles, data, color = color, linewidth = 2.5, linestyle = 'solid', label = row.tier)
    ax.fill(angles, data, color = color, alpha = 0.2)
    
for g in ax.yaxis.get_gridlines() :
    g.get_path()._interpolation_steps = len(labels)
 
spine = Spine(axes = ax,
          spine_type = 'circle',
          path = Path.unit_regular_polygon(len(labels)))

spine.set_transform(Affine2D().scale(.5).translate(.5, .5) + ax.transAxes)
           
ax.spines = {'polar' : spine} 

plt.legend(loc=(0.9, 0.9))
plt.show()

# %%
#JUG_stats_by_tier
labels = JUG.columns[1:]
num_labels = len(labels)
    
angles = [x / float(num_labels) * (2 * pi) for x in range(num_labels)] 
angles += angles[:1] 
    
my_palette = plt.cm.get_cmap("Set2", len(JUG.index))
 
fig = plt.figure(figsize=(8, 8))
fig.set_facecolor('white')
ax = fig.add_subplot(polar = True)
for i, row in JUG.iterrows():
    color = my_palette(i)
    data = JUG.iloc[i].drop('tier').tolist()
    data += data[:1]
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[: -1], labels, fontsize = 13)
    ax.tick_params(axis='x', which='major', pad = 15)
    
    ax.set_rlabel_position(0)
    plt.yticks([0, 1, 2, 3],['0', '1', '2', '3'], fontsize=10)
    plt.ylim(0, 3)
    
    ax.plot(angles, data, color = color, linewidth = 2.5, linestyle = 'solid', label = row.tier)
    ax.fill(angles, data, color = color, alpha = 0.2)
    
for g in ax.yaxis.get_gridlines() :
    g.get_path()._interpolation_steps = len(labels)
 
spine = Spine(axes = ax,
          spine_type = 'circle',
          path = Path.unit_regular_polygon(len(labels)))

spine.set_transform(Affine2D().scale(.5).translate(.5, .5) + ax.transAxes)
           
ax.spines = {'polar' : spine} 

plt.legend(loc=(0.9, 0.9))
plt.show()

# %%
#MID_stats_by_tier
labels = MID.columns[1:]
num_labels = len(labels)
    
angles = [x / float(num_labels) * (2 * pi) for x in range(num_labels)] 
angles += angles[:1] 
    
my_palette = plt.cm.get_cmap("Set2", len(MID.index))
 
fig = plt.figure(figsize=(8, 8))
fig.set_facecolor('white')
ax = fig.add_subplot(polar = True)
for i, row in MID.iterrows():
    color = my_palette(i)
    data = MID.iloc[i].drop('tier').tolist()
    data += data[:1]
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[: -1], labels, fontsize = 13)
    ax.tick_params(axis='x', which='major', pad = 15)
    
    ax.set_rlabel_position(0)
    plt.yticks([0, 1, 2, 3],['0', '1', '2', '3'], fontsize=10)
    plt.ylim(0, 3)
    
    ax.plot(angles, data, color = color, linewidth = 2.5, linestyle = 'solid', label = row.tier)
    ax.fill(angles, data, color = color, alpha = 0.2)
    
for g in ax.yaxis.get_gridlines() :
    g.get_path()._interpolation_steps = len(labels)
 
spine = Spine(axes = ax,
          spine_type = 'circle',
          path = Path.unit_regular_polygon(len(labels)))

spine.set_transform(Affine2D().scale(.5).translate(.5, .5) + ax.transAxes)
           
ax.spines = {'polar' : spine} 

plt.legend(loc=(0.9, 0.9))
plt.show()

# %%
#AD_stats_by_tier
labels = AD.columns[1:]
num_labels = len(labels)
    
angles = [x / float(num_labels) * (2 * pi) for x in range(num_labels)] 
angles += angles[:1] 
    
my_palette = plt.cm.get_cmap("Set2", len(AD.index))
 
fig = plt.figure(figsize=(8, 8))
fig.set_facecolor('white')
ax = fig.add_subplot(polar = True)
for i, row in AD.iterrows():
    color = my_palette(i)
    data = AD.iloc[i].drop('tier').tolist()
    data += data[:1]
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[: -1], labels, fontsize = 13)
    ax.tick_params(axis='x', which='major', pad = 15)
    
    ax.set_rlabel_position(0)
    plt.yticks([0, 1, 2, 3],['0', '1', '2', '3'], fontsize=10)
    plt.ylim(0, 3)
    
    ax.plot(angles, data, color = color, linewidth = 2.5, linestyle = 'solid', label = row.tier)
    ax.fill(angles, data, color = color, alpha = 0.2)
    
for g in ax.yaxis.get_gridlines() :
    g.get_path()._interpolation_steps = len(labels)
 
spine = Spine(axes = ax,
          spine_type = 'circle',
          path = Path.unit_regular_polygon(len(labels)))

spine.set_transform(Affine2D().scale(.5).translate(.5, .5) + ax.transAxes)
           
ax.spines = {'polar' : spine} 

plt.legend(loc=(0.9, 0.9))
plt.show()

# %%
#SUP_stats_by_tier
labels = SUP.columns[1:]
num_labels = len(labels)
    
angles = [x / float(num_labels) * (2 * pi) for x in range(num_labels)] 
angles += angles[:1] 
    
my_palette = plt.cm.get_cmap("Set2", len(SUP.index))
 
fig = plt.figure(figsize=(8, 8))
fig.set_facecolor('white')
ax = fig.add_subplot(polar = True)
for i, row in SUP.iterrows():
    color = my_palette(i)
    data = SUP.iloc[i].drop('tier').tolist()
    data += data[:1]
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[: -1], labels, fontsize = 13)
    ax.tick_params(axis='x', which='major', pad = 15)
    
    ax.set_rlabel_position(0)
    plt.yticks([0, 1, 2, 3],['0', '1', '2', '3'], fontsize=10)
    plt.ylim(0, 3)
    
    ax.plot(angles, data, color = color, linewidth = 2.5, linestyle = 'solid', label = row.tier)
    ax.fill(angles, data, color = color, alpha = 0.2)
    
for g in ax.yaxis.get_gridlines() :
    g.get_path()._interpolation_steps = len(labels)
 
spine = Spine(axes = ax,
          spine_type = 'circle',
          path = Path.unit_regular_polygon(len(labels)))

spine.set_transform(Affine2D().scale(.5).translate(.5, .5) + ax.transAxes)
           
ax.spines = {'polar' : spine} 

plt.legend(loc=(0.9, 0.9))
plt.show()

# %%
# LOW_TIER_TOP_mean

# %%
# # Top stats by tier
# categories = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']
# categories = [*categories, categories[0]]

# LOW_TIER_TOP_stats = [*LOW_TIER_TOP_stats, LOW_TIER_TOP_stats[0]]
# MID_TIER_TOP_stats = [*MID_TIER_TOP_stats, MID_TIER_TOP_stats[0]]
# HIGH_TIER_TOP_stats = [*HIGH_TIER_TOP_stats, HIGH_TIER_TOP_stats[0]]

# label_loc = np.linspace(start = 0, stop = 2*np.pi, num = len(LOW_TIER_TOP_stats))


# plt.figure(figsize = (8, 8))
# ax = plt.subplot(polar = True)
# plt.xticks(label_loc, labels = categories, fontsize = 13)
# plt.ylim(1, 3)
# ax.plot(label_loc, LOW_TIER_TOP_stats, label = 'LOW_TIER_TOP', linestyle = 'dashed', color = 'red')
# ax.fill(label_loc, LOW_TIER_TOP_stats, 'red', alpha = 1)
# ax.plot(label_loc, MID_TIER_TOP_stats, label = 'MID_TIER_TOP', linestyle = 'dashed', color = 'green')
# ax.fill(label_loc, MID_TIER_TOP_stats, 'green', alpha = 1)
# ax.plot(label_loc, HIGH_TIER_TOP_stats, label = 'HIGH_TIER_TOP', linestyle = 'dashed', color = 'skyblue')
# ax.fill(label_loc, HIGH_TIER_TOP_stats, 'skyblue', alpha = 1)

# ax.legend()
# #ax.show()

# %%
# # JG stats by tier
# categories = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']
# categories = [*categories, categories[0]]

# LOW_TIER_JUG_stats = [*LOW_TIER_JUG_stats, LOW_TIER_JUG_stats[0]]
# MID_TIER_JUG_stats = [*MID_TIER_JUG_stats, MID_TIER_JUG_stats[0]]
# HIGH_TIER_JUG_stats = [*HIGH_TIER_JUG_stats, HIGH_TIER_JUG_stats[0]]

# label_loc = np.linspace(start = 0, stop = 2*np.pi, num = len(LOW_TIER_JUG_stats))

# plt.figure(figsize = (8, 8))
# ax = plt.subplot(polar = True)
# plt.xticks(label_loc, labels = categories, fontsize = 13)
# plt.ylim(0, 3.2)
# ax.plot(label_loc, LOW_TIER_JUG_stats, label = 'LOW_TIER_JUG', linestyle = 'dashed', color = 'lightcoral')
# ax.fill(label_loc, LOW_TIER_JUG_stats, 'lightcoral', alpha = 0.4)
# ax.plot(label_loc, MID_TIER_JUG_stats, label = 'MID_TIER_JUG', linestyle = 'dashed', color = 'violet')
# ax.fill(label_loc, MID_TIER_JUG_stats, 'violet', alpha = 0.4)
# ax.plot(label_loc, HIGH_TIER_JUG_stats, label = 'HIGH_TIER_JUG_stats', linestyle = 'dashed', color = 'skyblue')
# ax.fill(label_loc, HIGH_TIER_JUG_stats, 'skyblue', alpha = 0.4)

# ax.legend()
# #ax.show()

# %%
# # MID stats by tier
# categories = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']
# categories = [*categories, categories[0]]

# LOW_TIER_MID_stats = [*LOW_TIER_MID_stats, LOW_TIER_MID_stats[0]]
# MID_TIER_MID_stats = [*MID_TIER_MID_stats, MID_TIER_MID_stats[0]]
# HIGH_TIER_MID_stats = [*HIGH_TIER_MID_stats, HIGH_TIER_MID_stats[0]]

# label_loc = np.linspace(start = 0, stop = 2*np.pi, num = len(LOW_TIER_MID_stats))

# plt.figure(figsize = (8, 8))
# ax = plt.subplot(polar = True)
# plt.xticks(label_loc, labels = categories, fontsize = 13)
# plt.ylim(0, 3.2)
# ax.plot(label_loc, LOW_TIER_MID_stats, label = 'LOW_TIER_MID', linestyle = 'dashed', color = 'lightcoral')
# ax.fill(label_loc, LOW_TIER_MID_stats, 'lightcoral', alpha = 0.4)
# ax.plot(label_loc, MID_TIER_MID_stats, label = 'MID_TIER_MID', linestyle = 'dashed', color = 'violet')
# ax.fill(label_loc, MID_TIER_MID_stats, 'violet', alpha = 0.4)
# ax.plot(label_loc, HIGH_TIER_MID_stats, label = 'HIGH_TIER_MID', linestyle = 'dashed', color = 'skyblue')
# ax.fill(label_loc, HIGH_TIER_MID_stats, 'skyblue', alpha = 0.4)

# ax.legend()
# #ax.show()

# %%
# # AD stats by tier
# categories = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']
# categories = [*categories, categories[0]]

# LOW_TIER_AD_stats = [*LOW_TIER_AD_stats, LOW_TIER_AD_stats[0]]
# MID_TIER_AD_stats = [*MID_TIER_AD_stats, MID_TIER_AD_stats[0]]
# HIGH_TIER_AD_stats = [*HIGH_TIER_AD_stats, HIGH_TIER_AD_stats[0]]

# label_loc = np.linspace(start = 0, stop = 2*np.pi, num = len(LOW_TIER_AD_stats))

# plt.figure(figsize = (8, 8))
# ax = plt.subplot(polar = True)
# plt.xticks(label_loc, labels = categories, fontsize = 13)
# plt.ylim(0, 3)
# ax.plot(label_loc, LOW_TIER_AD_stats, label = 'LOW_TIER_AD', linestyle = 'dashed', color = 'lightcoral')
# ax.fill(label_loc, LOW_TIER_AD_stats, 'lightcoral', alpha = 0.4)
# ax.plot(label_loc, MID_TIER_AD_stats, label = 'MID_TIER_AD', linestyle = 'dashed', color = 'violet')
# ax.fill(label_loc, MID_TIER_AD_stats, 'violet', alpha = 0.4)
# ax.plot(label_loc, HIGH_TIER_AD_stats, label = 'HIGH_TIER_AD', linestyle = 'dashed', color = 'skyblue')
# ax.fill(label_loc, HIGH_TIER_AD_stats, 'skyblue', alpha = 0.4)

# ax.legend()
# #ax.show()

# %%
# # SUP stats by tier
# categories = ['damage', 'durability', 'crowdControl', 'mobility', 'utility']
# categories = [*categories, categories[0]]

# LOW_TIER_SUP_stats = [*LOW_TIER_SUP_stats, LOW_TIER_SUP_stats[0]]
# MID_TIER_SUP_stats = [*MID_TIER_SUP_stats, MID_TIER_SUP_stats[0]]
# HIGH_TIER_SUP_stats = [*HIGH_TIER_SUP_stats, HIGH_TIER_SUP_stats[0]]

# label_loc = np.linspace(start = 0, stop = 2*np.pi, num = len(LOW_TIER_SUP_stats))

# plt.figure(figsize = (8, 8))
# ax = plt.subplot(polar = True)
# plt.xticks(label_loc, labels = categories, fontsize = 13)
# plt.ylim(0, 3)
# ax.plot(label_loc, LOW_TIER_SUP_stats, label = 'LOW_TIER_SUP', linestyle = 'dashed', color = 'lightcoral')
# ax.fill(label_loc, LOW_TIER_SUP_stats, 'lightcoral', alpha = 0.4)
# ax.plot(label_loc, MID_TIER_SUP_stats, label = 'MID_TIER_SUP', linestyle = 'dashed', color = 'violet')
# ax.fill(label_loc, MID_TIER_SUP_stats, 'violet', alpha = 0.4)
# ax.plot(label_loc, HIGH_TIER_SUP_stats, label = 'HIGH_TIER_SUP', linestyle = 'dashed', color = 'skyblue')
# ax.fill(label_loc, HIGH_TIER_SUP_stats, 'skyblue', alpha = 0.4)

# ax.legend()
# #ax.show()
